# %%
import pandas as pd
from IPython.core.display import HTML

# %%
patterns_df = pd.read_csv("../contextSub/resources/pubchemFPKeys_to_SMARTSpattern_filtered.csv")

# %%
patterns_df
# Out:
#      Unnamed: 0    PubChem_pattern                              SMARTS  \
# 0            66         C(~Br)(~H)                 [#6](~[#35])(~[#1])
# 1            68         C(~Br)(:N)                 [#6](~[#35])(:[#7])
# 2            72  C(~C)(~C)(~C)(~H)    [#6](~[#6])(~[#6])(~[#6])(~[#1])
# 3            73  C(~C)(~C)(~C)(~N)    [#6](~[#6])(~[#6])(~[#6])(~[#7])
# 4            74  C(~C)(~C)(~C)(~O)    [#6](~[#6])(~[#6])(~[#6])(~[#8])
# ..          ...                ...                                 ...
# 332         613        NC1C(Cl)CC1       [#7][#6]1[#6]([#17])[#6][#6]1
# 333         614       NC1C(Br)CCC1   [#7][#6]1[#6]([#35])[#6][#6][#6]1
# 334         615      ClC1C(Cl)CCC1  [#17][#6]1[#6]([#17])[#6][#6][#6]1
# 335         616      ClC1C(Br)CCC1  [#17][#6]1[#6]([#35])[#6][#6][#6]1
# 336         617      BrC1C(Br)CCC1  [#35][#6]1[#6]([#35])[#6][#6][#6]1
#
#                                        images
# 0     ../data/pubchemfp_pattern_images/66.png
# ...

# %%
def path_to_image_html(path, width=240):
    return f'<img src="{path}" width="{width}" >'

# %%
HTML(patterns_df.to_html(escape=False, formatters=dict(images=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>PubChem_pattern</th>
#       <th>SMARTS</th>
#       <th>images</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>66</td>
#       <td>C(~Br)(~H)</td>
#       <td>[#6](~[#35])(~[#1])</td>
#       <td><img src="../data/pubchemfp_pattern_images/66.png" width="240" ></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>68</td>
#       <td>C(~Br)(:N)</td>
#       <td>[#6](~[#35])(:[#7])</td>
#       <td><img src="../data/pubchemfp_pattern_images/68.png" width="240" ></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>72</td>
#       <td>C(~C)(~C)(~C)(~H)</td>
#       <td>[#6](~[#6])(~[#6])(~[#6])(~[#1])</td>
#       <td><img src="../data/pubchemfp_pattern_images/72.png" width="240" ></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>73</td>
#       <td>C(~C)(~C)(~C)(~N)</td>
# ...
