# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import pickle as pk
from itertools import tee
from math import ceil
import statistics
import sys
sys.path.append("..")

import matplotlib
matplotlib.use("nbagg")
import matplotlib.pyplot as plt
plt.ioff()
import yaml

from results_analyzers.analyzers import Renamer, Plotter, Comparer

# %%
ROOT_PATH = os.path.join(os.path.pardir, "logs", "GIN", "20200715_with_multilevel_freezing")

# %% [markdown]
# ## Rename results

# %%
required_fields = [
    "data_ratio",
    "encoder_dataset",
    "classifier_dataset",
    "encoder_epochs",
    "frozen_epochs",
    "aggregation"
]
rn = Renamer(required_fields=required_fields)

# %%
for date in os.scandir(ROOT_PATH):
    for task in os.scandir(date.path):
        rn.rename_results(task.path)

# %% [markdown]
# ## Plot results

# %% [markdown]
# ### BACE dataset

# %%
plter = Plotter(os.path.join(ROOT_PATH, "20200711_025817", "ZINC1k_BACE"))
fig, axes = plter.plot_results(identifiers={"new": "5", "old": "10"}, ncols=2, figsize=[8, 8],ylim=[0.4, 1])
fig.show()
fig.savefig(os.path.join(ROOT_PATH, "20200711_025817", "ZINC1k_BACE", "AP.png"))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### BBBP dataset

# %%
plter = Plotter(os.path.join(ROOT_PATH, "20200711_035711", "ZINC1k_BBBP"))
fig, axes = plter.plot_results(identifiers={"new": "5", "old": "10"}, ncols=2, figsize=[8, 8],ylim=[0.4, 1])
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### ClinTox dataset

# %%
plter = Plotter(os.path.join(ROOT_PATH, "20200711_045832", "ZINC1k_ClinTox"))
fig, axes = plter.plot_results(identifiers={"new": "5", "old": "10"}, ncols=2, figsize=[8, 16],ylim=[0, 0.8])
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### HIV dataset

# %%
plter = Plotter(os.path.join(ROOT_PATH, "20200711_060625", "ZINC1k_HIV"))
fig, axes = plter.plot_results(identifiers={"new": "5", "old": "10"}, ncols=2, figsize=[8, 16],ylim=[0, 0.9])
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Sider dataset

# %%
plter = Plotter(os.path.join(ROOT_PATH, "20200712_043302", "ZINC1k_Sider"))
fig, axes = plter.plot_results(identifiers={"new": "5", "old": "10"}, ncols=2, figsize=[8, 8],ylim=[0.5, 0.7])
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### JAK1 dataset

# %%
plter = Plotter(os.path.join(ROOT_PATH, "20200712_053211", "JAK1Dude_JAK1"))
fig, axes = plter.plot_results(identifiers={"new": "5", "old": "10"}, ncols=2, figsize=[8, 8],ylim=[0.8, 1])
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### JAK2 dataset

# %%
plter = Plotter(os.path.join(ROOT_PATH, "20200712_152742", "JAK2Dude_JAK2"))
fig, axes = plter.plot_results(identifiers={"new": "5", "old": "10"}, ncols=2, figsize=[8, 8],ylim=[0.5, 1])
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### JAK3 dataset

# %%
plter = Plotter(os.path.join(ROOT_PATH, "20200713_093400", "JAK3Dude_JAK3"))
fig, axes = plter.plot_results(identifiers={"new": "5", "old": "10"}, ncols=2, figsize=[8, 8],ylim=[0.5, 1])
fig.show()
fig.savefig(os.path.join(ROOT_PATH, "20200713_093400", "JAK3Dude_JAK3", "AP.png"))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Amu dataset

# %%
p1 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "mean_Amu_0.1_Repurposing_0_5")
p2 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "mean_Amu_0.1_Repurposing_10000_5")
comp = Comparer(p1, p2)

fig, axe = comp.plot(figsize=[6, 4], ylim=[0, 0.2], labels=["AP_nopre_mean", "AP_pre_mean"])
p3 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "sum_Amu_0.1_Repurposing_0_5")
p4 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "sum_Amu_0.1_Repurposing_10000_5")
comp.path1, comp.path2 = p3, p4
comp.plot(axe=axe, figsize=[6, 4], ylim=[0, 0.125], labels=["AP_nopre_sum", "AP_pre_sum"])
axe.set_title("Amu_0.1")
fig.savefig(os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "ratio_0.1_optimized_fine-tunining.png"))
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
p1 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "mean_Amu_0.5_Repurposing_0_5")
p2 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "mean_Amu_0.5_Repurposing_10000_5")
comp = Comparer(p1, p2)

fig, axe = comp.plot(figsize=[6, 4], ylim=[0, 0.2], labels=["AP_nopre_mean", "AP_pre_mean"])
p3 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "sum_Amu_0.5_Repurposing_0_5")
p4 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "sum_Amu_0.5_Repurposing_10000_5")
comp.path1, comp.path2 = p3, p4
comp.plot(axe=axe, figsize=[6, 4], ylim=[0, 0.15], labels=["AP_nopre_sum", "AP_pre_sum"])
axe.set_title("Amu_0.5")
fig.savefig(os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "ratio_0.5_optimized_fine-tunining.png"))
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
p1 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "mean_Amu_0.9_Repurposing_0_5")
p2 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "mean_Amu_0.9_Repurposing_10000_5")
comp = Comparer(p1, p2)

fig, axe = comp.plot(figsize=[6, 4], ylim=[0, 0.3], labels=["AP_nopre_mean", "AP_pre_mean"])
p3 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "sum_Amu_0.9_Repurposing_0_5")
p4 = os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "sum_Amu_0.9_Repurposing_10000_5")
comp.path1, comp.path2 = p3, p4
comp.plot(axe=axe, figsize=[6, 4], ylim=[0, 0.3], labels=["AP_nopre_sum", "AP_pre_sum"])
axe.set_title("Amu_0.9")
fig.savefig(os.path.join(ROOT_PATH, "20200714_004031", "Repurposing_Amu", "ratio_0.9_optimized_fine-tunining.png"))
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
p1 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "mean_Ellinger_0.1_Repurposing_0_5")
p2 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "mean_Ellinger_0.1_Repurposing_10000_5")
comp = Comparer(p1, p2, metric="validating_ROC_AUC")

fig, axe = comp.plot(figsize=[6, 4], ylim=[0, 0.04], labels=["AP_nopre_mean", "AP_pre_mean"])
p3 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "sum_Ellinger_0.1_Repurposing_0_5")
p4 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "sum_Ellinger_0.1_Repurposing_10000_5")
comp.path1, comp.path2 = p3, p4
comp.plot(axe=axe, figsize=[6, 4], ylim=[0, 1], labels=["AP_nopre_sum", "AP_pre_sum"])
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
p1 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "mean_Ellinger_0.5_Repurposing_0_10")
p2 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "mean_Ellinger_0.5_Repurposing_10000_10")
comp = Comparer(p1, p2, metric="validating_ROC_AUC")

fig, axe = comp.plot(figsize=[6, 4], ylim=[0, 0.08], labels=["AP_nopre_mean", "AP_pre_mean"])
p3 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "sum_Ellinger_0.5_Repurposing_0_10")
p4 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "sum_Ellinger_0.5_Repurposing_10000_10")
comp.path1, comp.path2 = p3, p4
comp.plot(axe=axe, figsize=[6, 4], ylim=[0, 1], labels=["AP_nopre_sum", "AP_pre_sum"])
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
p1 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "mean_Ellinger_0.9_Repurposing_0_5")
p2 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "mean_Ellinger_0.9_Repurposing_10000_5")
comp = Comparer(p1, p2, metric="validating_ROC_AUC")

fig, axe = comp.plot(figsize=[6, 4], ylim=[0, 1], labels=["AP_nopre_mean", "AP_pre_mean"])
p3 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "sum_Ellinger_0.9_Repurposing_0_5")
p4 = os.path.join(ROOT_PATH, "20200714_053442", "Repurposing_Ellinger", "sum_Ellinger_0.9_Repurposing_10000_5")
comp.path1, comp.path2 = p3, p4
comp.plot(axe=axe, figsize=[6, 4], ylim=[0, 1], labels=["AP_nopre_sum", "AP_pre_sum"])
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
p1 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "mean_Mpro_0.1_Repurposing_0_5")
p2 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "mean_Mpro_0.1_Repurposing_10000_5")
comp = Comparer(p1, p2, metric="validating_AP_AUC")

fig, axe = comp.plot(figsize=[6, 4], ylim=[0, 1], labels=["AP_nopre_mean", "AP_pre_mean"])
p3 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "sum_Mpro_0.1_Repurposing_0_5")
p4 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "sum_Mpro_0.1_Repurposing_10000_5")
comp.path1, comp.path2 = p3, p4
comp.plot(axe=axe, figsize=[6, 4], ylim=[0, 0.4], labels=["AP_nopre_sum", "AP_pre_sum"])
axe.set_title("Mpro_0.1")
fig.savefig(os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "ratio_0.1_optimized_fine-tunining.png"))
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
p1 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "mean_Mpro_0.5_Repurposing_0_5")
p2 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "mean_Mpro_0.5_Repurposing_10000_5")
comp = Comparer(p1, p2, metric="validating_AP_AUC")

fig, axe = comp.plot(figsize=[6, 4], ylim=[0, 1], labels=["AP_nopre_mean", "AP_pre_mean"])
p3 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "sum_Mpro_0.5_Repurposing_0_5")
p4 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "sum_Mpro_0.5_Repurposing_10000_5")
comp.path1, comp.path2 = p3, p4
comp.plot(axe=axe, figsize=[6, 4], ylim=[0, 0.6], labels=["AP_nopre_sum", "AP_pre_sum"])
axe.set_title("Mpro_0.5")
fig.savefig(os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "ratio_0.5_optimized_fine-tunining.png"))
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
p1 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "mean_Mpro_0.9_Repurposing_0_5")
p2 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "mean_Mpro_0.9_Repurposing_10000_5")
comp = Comparer(p1, p2, metric="validating_AP_AUC")

fig, axe = comp.plot(figsize=[6, 4], ylim=[0, 1], labels=["AP_nopre_mean", "AP_pre_mean"])
p3 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "sum_Mpro_0.9_Repurposing_0_5")
p4 = os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "sum_Mpro_0.9_Repurposing_10000_5")
comp.path1, comp.path2 = p3, p4
comp.plot(axe=axe, figsize=[6, 4], ylim=[0, 0.8], labels=["AP_nopre_sum", "AP_pre_sum"])
axe.set_title("Mpro_0.9")
fig.savefig(os.path.join(ROOT_PATH, "20200714_132016", "Repurposing_Mpro", "ratio_0.9_optimized_fine-tunining.png"))
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
plt.close("all")

# %%
logs\GIN\20200715_with_multilevel_freezing\20200714_132016\Repurposing_Mpro\mean_Mpro_0.1_Repurposing_0_5
